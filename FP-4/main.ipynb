# %% [markdown]
# # Final Project FP-3:  Descriptive Statistics
#
#
# <br>
# <br>

# %% [markdown]
# ___
#
# <br>
#
# # Analysis of risk factors of Coronary Artery Disease
#
#
# * **Name**:  Haaniya REHAN KAMAL
# * **Student number**:  B990378384
#
# <br>

# %% [markdown]
# ### Purpose:
#
# * <span style>The purpose of this Final Project is to analyse risk factors of coronary artery disease</span>
# * <span style>The key **dependent variable** is: Stage of disease </span>
# * <span style>The key **independent variables** include:
# * - Age
#   - sex
#   - resting blood sugar
#   - cholesterol level
#   - fasting blood sugar
#   - maximum heart rate achieved
#   - resting electrographic results
#   - number of blood vessels coloured (to indicate severity of disease)
#   - thalassemia defect type </span>
# * <span style>There are 297 cases, 1 dependent variable (stage of disease - ie. the presence of disease) and 9 independent variables.</span>
#
# <br>

# %% [markdown]
# ### Dataset source:
#
# <span style>The data is from a website and databank called Kaggle.
#
# <span style>The dataset can be accessed from [here](https://www.kaggle.com/datasets/agsam23/coronary-artery-disease/data)
#
# </span>

# %% [markdown]
# ___
#
# ## Descriptive Statistics

# %%
# %%capture
import descriptive
import parse_data

from descriptive import *

df = parse_data.parsedata

# %%
display_central_tendency_table(num=1)
display_dispersion_table(num=2)
# Out:
# <br><br><p><span style="font-size: 1.2em;"><b>Table 1</b>: Central tendency summary statistics.</span></p>
#          sex   age  blood pressure  cholesterol  Fasting Blood Sugar  restecg  \
# mean    0.68  54.5          131.69       247.35             0.144781      1.0
# median  1.00  56.0          130.00       243.00             0.000000      1.0
# mode    1.00  58.0          120.00       197.00             0.000000      0.0
#
#         thalach  exercise induced angina  severity of artery blockage
# mean      149.6                     0.33                        -0.68
# median    153.0                     0.00                         0.00
# mode      162.0                     0.00                        -0.00
# <br><br><p><span style="font-size: 1.2em;"><b>Table 2</b>: Dispersion summary statistics.</span></p>
#           sex   age  blood pressure  cholesterol  Fasting Blood Sugar  \
# st.dev.  0.47   9.0           17.73        51.91              0.35188
# ...

# %% [markdown]
# ---
#
# **Question:** Which continous numerical independant variable has the strongest correlation with the severity of coronary artery disease?

# %%
plot_descriptive()
# Out:
# <p><span style="font-size: 1.2em;"><b>Figure 1</b>: Correlations amongst main variables.</span></p><br><br>

# %% [markdown]
# **Answer**: The correlation coefficients are all relatively low. The strongest correlation is seen in maximum heart rate with severity of disease, suggesting that the more severe the coronary artery disease is, the more the heart may be compensating for the lack of blood supply by increasing heart rate.
# <br/>
# Further exploring heart rate and severity of disease did not show significant findings.
#
# ---

# %% [markdown]
# **Question:** What is the most common age group and distribution of age groups affected by Coronary Artery Disease?

# %%
plot_agedistribution()
# Out:
# <p><span style="font-size: 1.2em;"><b>Figure 2</b>: Distribution of Age</span></p><br><br>

# %% [markdown]
# **Answer:** The most common age group is 50-59 years old, with the mean and median around 55 years old. As the mean and median are quite similar, and the data is normally distributed, it can also be seen as the average age and a good representation of the central tendency.
#
# ---

# %% [markdown]
# **Question:** Is coronary artery disease more common in females or males?

# %% [markdown]
# **Answer:** Out of a sample of around 300 cases, 2/3 (201) of the patients were male - suggesting a higher prevalence in men.
#
# ---

# %% [markdown]
# **Question:** What is the most popular heart abnormality pattern amongst males and females?

# %%
plot_ecg()
# Out:
# <p><span style="font-size: 1.2em;"><b>Figure 3</b>: Heart Activity Abnormality in Female vs Male Patients</span></p><br><br>

# %% [markdown]
# **Answer:** ST-T wave abnormalities are rare and are more prevalent in females than males. Overall left ventricular hypertrophy is much more common for coronary artery disease patients and is largely more common in male patients.
# <br/>
#
# ---

# %% [markdown]
# **Question:** Is the average age of female or male patients lower than the other?

# %% [markdown]
# **Answer:** Female average age, 55.8, is technically higher by just under 2 years, however they both lie within the same age group of 50-59 so it is not as significant.
