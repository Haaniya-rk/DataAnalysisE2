# %% [markdown]
# # Analysis of risk factors for Coronary Artery Disease (CAD)
# ## Machine Learning

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %%capture

# %run machineFP6.ipynb

# %% [markdown]
# ### Result 1: Accuracy results with KNN for predicting CAD

# %%
table = KNNtable(df)
plt.show()

# %% [markdown]
# The accuracy score for KNN prediction of CAD varies as the grouping for severity of coronary artery blockage varies in its binary categorisation into 'CAD' and 'no CAD'. As the conditions for CAD become more lenient, such as including a less severe artery blockage angiogram result to still classify as CAD, the accuracy increases. Although this improves accuracy of the prediction system, this has implications such as predicting false cases of coronary artery disease due to false diagnosis regarding their angiogram results.

# %% [markdown]
# ### Result 2: Effect of changing alpha value on classification rate results for MLP

# %%
graph = CRgraph(df)
plt.show()

# %% [markdown]
# The results show that the classification rate and alpha value do not have a typical linear and plateau relationship. Rather, the highest classification rate is achieved with an alpha value of 2. This shows that the data is not geometrically complex, due to its nature as a medical dataset with intricately related variables and thus does not benefit from a lower alpha value.
